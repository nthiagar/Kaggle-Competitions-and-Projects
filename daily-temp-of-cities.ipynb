# %% [markdown]
# Hello and welcome to this notebook where we will be going over average temperature increase/decrease and plotting it so that we can visualize it clearly!

# %%
import pandas as pd
import geopandas as gpd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
temp_data=pd.read_csv("../input/daily-temperature-of-major-cities/city_temperature.csv", index_col="Country", usecols=['Country', 'City', 'Month','Day', 'Year', 'AvgTemperature'])
temp_data.index = temp_data.index.str.replace('US','United States')

# %% [markdown]
# Since we have read our data in we need to make sure that no bad data is in here. We are only going to be dealing with the years 1995 and 2019 to see the variation of temperaure over time so we need to remove NAN values (which is why we dropped the state column) and temperatures like -99 which don't make sense.

# %% [markdown]
# We are handling temperatures from 1995 and sorting that data by the Country, City, Month and Day. Also we are making sure that -99 is removed from the dataset.

# %%
past_temp_data =temp_data.loc[temp_data.Year.isin(['1995'])]
temp_1995=past_temp_data.loc[:,['City', 'Month', 'Day', 'AvgTemperature']]
temp_1995_filtered = temp_1995[temp_1995['AvgTemperature'] != -99.0] 
temp_1995_filtered.loc[temp_1995_filtered.City == 'Algiers']
temp_1995_filtered
# Out:
#                                City  Month  Day  AvgTemperature
# Country
# Algeria                     Algiers      1    1            64.2
# Algeria                     Algiers      1    2            49.4
# Algeria                     Algiers      1    3            48.8
# Algeria                     Algiers      1    4            46.4
# Algeria                     Algiers      1    5            47.9
# ...                             ...    ...  ...             ...
# United States  San Juan Puerto Rico     12   27            79.5
# United States  San Juan Puerto Rico     12   28            80.6
# United States  San Juan Puerto Rico     12   29            78.8
# United States  San Juan Puerto Rico     12   30            80.1
# United States  San Juan Puerto Rico     12   31            79.2
#
# [112152 rows x 4 columns]

# %% [markdown]
# Now we are doing the same thing, but with 2019 so we can compare both data sets.

# %%
future_temp_data =temp_data.loc[temp_data.Year.isin(['2019'])]
temp_2019=future_temp_data.loc[:,['City', 'Month','Day', 'AvgTemperature']]
temp_2019_filtered = temp_2019[temp_2019['AvgTemperature'] != -99.0] 
temp_2019_filtered
# Out:
#                    City  Month  Day  AvgTemperature
# Country
# Algeria         Algiers      1    1            50.6
# Algeria         Algiers      1    2            49.9
# Algeria         Algiers      1    3            50.9
# Algeria         Algiers      1    4            50.6
# Algeria         Algiers      1    5            49.7
# ...                 ...    ...  ...             ...
# United States  Cheyenne     12   27            25.1
# United States  Cheyenne     12   28            23.3
# United States  Cheyenne     12   29            17.5
# United States  Cheyenne     12   30            17.6
# United States  Cheyenne     12   31            24.5
#
# [105085 rows x 4 columns]

# %% [markdown]
# Now we will merge the data into one data set so it is easy to compare them and take the difference of the temperatures of 2019 and 1995 and sort it by the Month and Day so we can eventually find the average temperature difference from 1995 to 2019.

# %%
merged_temp_df=pd.merge(temp_2019_filtered, temp_1995_filtered, on=['Country', 'City', 'Month', 'Day'], how='inner')
merged_temp_df['Temp_Difference']=merged_temp_df['AvgTemperature_x']-merged_temp_df['AvgTemperature_y']
merged_temp_df.head()
# Out:
#             City  Month  Day  AvgTemperature_x  AvgTemperature_y  \
# Country
# Algeria  Algiers      1    1              50.6              64.2
# Algeria  Algiers      1    2              49.9              49.4
# Algeria  Algiers      1    3              50.9              48.8
# Algeria  Algiers      1    4              50.6              46.4
# Algeria  Algiers      1    5              49.7              47.9
#
#          Temp_Difference
# Country
# Algeria            -13.6
# Algeria              0.5
# Algeria              2.1
# Algeria              4.2
# Algeria              1.8

# %% [markdown]
# Now that we have the 'Temp_Difference' column we can take the mean of the differences by Month and Day so we have one solid average differnce for each World City.

# %%
temp_difference_df=merged_temp_df.groupby(['Country', 'City']).Temp_Difference.mean()
final_temp_df=temp_difference_df.sort_values(ascending=False)
final_temp_df=final_temp_df.to_frame()
print(final_temp_df.to_string())
# Out:
#                                                Temp_Difference
# Country                  City
# United States            Anchorage                    5.279726
# Poland                   Warsaw                       5.050975
# United States            Fairbanks                    4.727123
# Romania                  Bucharest                    4.563510
# Kazakhstan               Almaty                       4.484123
# Italy                    Milan                        4.480392
# Japan                    Osaka                        4.477994
# United Arab Emirates     Dubai                        4.423120
# Yugoslavia               Belgrade                     3.992201
# Hungary                  Budapest                     3.801671
# Bulgaria                 Sofia                        3.785237
# Qatar                    Doha                         3.767409
# Austria                  Vienna                       3.745278
# Bahrain                  Manama                       3.699721
# Czech Republic           Prague                       3.699443
# United States            Chattanooga                  3.656164
# Slovakia                 Bratislava                   3.645404
# Belarus                  Minsk                        3.608897
# Turkey                   Istanbul                     3.552646
# Iceland                  Reykjavik                    3.518663
# China                    Shanghai                     3.513370
# United States            Charlotte                    3.473425
# Saudi Arabia             Dhahran                      3.467688
# United Arab Emirates     Abu Dhabi                    3.461281
# South Korea              Seoul                        3.438162
# United States            Huntsville                   3.436712
# Australia                Melbourne                    3.252089
# United States            Asheville                    3.244110
#                          Lexington                    3.229589
#                          Akron Canton                 3.226301
# Hong Kong                Hong Kong                    3.207799
# Ukraine                  Kiev                         3.101662
# United States            Atlantic City                3.087945
# Russia                   Moscow                       3.085794
# Denmark                  Copenhagen                   3.054596
# Egypt                    Cairo                        3.051253
# China                    Guangzhou                    3.044290
# Australia                Sydney                       2.987187
# India                    Chennai (Madras)             2.975766
# Philippines              Manila                       2.960167
# Uzbekistan               Tashkent                     2.944847
# United States            Atlanta                      2.921096
# Vietnam                  Hanoi                        2.889415
# Saudi Arabia             Riyadh                       2.888301
# United States            Macon                        2.831233
#                          Jacksonville                 2.811781
# Macedonia                Skopje                       2.779656
# United States            Louisville                   2.754521
# Namibia                  Windhoek                     2.713623
# United States            Dayton                       2.712877
#                          Birmingham                   2.704132
#                          Tampa St. Petersburg         2.697534
# Turkey                   Ankara                       2.690251
# Kuwait                   Kuwait                       2.689888
# United States            Roanoke                      2.677260
#                          Tupelo                       2.668493
# China                    Chengdu                      2.624513
# United States            Nashville                    2.623562
#                          Greensboro                   2.604384
# Uruguay                  Montvideo                    2.566574
# Taiwan                   Taipei                       2.564624
# Brazil                   Brasilia                     2.554444
# United States            Richmond                     2.516712
#                          Juneau                       2.513462
#                          Knoxville                    2.505479
#                          New Orleans                  2.503288
#                          Washington                   2.499452
#                          Washington DC                2.499452
# Switzerland              Zurich                       2.463687
# United States            Cincinnati                   2.461096
# Latvia                   Riga                         2.453352
# United States            Montgomery                   2.440274
# Australia                Canberra                     2.412813
# United States            Columbus                     2.409178
#                          Columbia                     2.397808
#                          Tallahassee                  2.366849
#                          Orlando                      2.315068
# Colombia                 Bogota                       2.282682
# United States            Charleston                   2.278767
# North Korea              Pyongyang                    2.274930
# United States            Savannah                     2.226849
#                          West Palm Beach              2.220274
# Tajikistan               Dusanbe                      2.220000
# Syria                    Damascus                     2.190449
# United States            Raleigh Durham               2.183836
# Italy                    Rome                         2.173538
# Norway                   Oslo                         2.167688
# United States            Norfolk                      2.137808
#                          Allentown                    2.137534
# Germany                  Munich                       2.118379
# Switzerland              Geneva                       2.089972
# United States            Mobile                       2.076438
# Bahamas                  Nassau                       2.070950
# United States            Pueblo                       2.070137
#                          Brownsville                  2.046027
# Sweden                   Stockholm                    2.026741
# Lebanon                  Beirut                       1.937430
# Australia                Brisbane                     1.927855
# United States            Abilene                      1.926301
# Jordan                   Amman                        1.913649
# Dominican Republic       Santo Domingo                1.897297
# United States            Miami Beach                  1.852055
# India                    Bombay (Mumbai)              1.839665
# United States            Boston                       1.811507
# Tanzania                 Dar Es Salaam                1.802632
# Turkmenistan             Ashabad                      1.799443
# Brazil                   Sao Paulo                    1.796657
# Nicaragua                Managua                      1.785366
# Indonesia                Jakarta                      1.756507
# South Africa             Capetown                     1.755710
# United States            Midland Odessa               1.714521
# Finland                  Helsinki                     1.693872
# United States            Cleveland                    1.685753
#                          Youngstown                   1.649863
# Japan                    Tokyo                        1.627019
# United States            Jackson                      1.598356
# China                    Shenyang                     1.593036
# Singapore                Singapore                    1.587465
# United States            Fort Smith                   1.580548
#                          San Francisco                1.579452
# The Netherlands          Amsterdam                    1.565181
# United States            Reno                         1.557534
#                          Fresno                       1.545753
# Malaysia                 Kuala Lumpur                 1.446218
# United States            Colorado Springs             1.424658
# Nigeria                  Niamey                       1.394068
# Uganda                   Kampala                      1.334021
# Argentina                Buenos Aires                 1.332033
# Venezuela                Caracas                      1.321037
# Pakistan                 Islamabad                    1.312500
# United States            Wichita                      1.303836
# Central African Republic Bangui                       1.293200
# United States            Memphis                      1.270411
#                          Flint                        1.261096
#                          Erie                         1.231507
#                          Paducah                      1.209863
# Mexico                   Mexico City                  1.200279
# India                    Delhi                        1.199437
# United States            Lansing                      1.184658
#                          San Angelo                   1.175342
# Australia                Perth                        1.141111
# Pakistan                 Karachi                      1.107521
# United States            Indianapolis                 1.101644
#                          Toledo                       1.085753
# Mexico                   Guadalajara                  1.074359
# United States            Waco                         1.072527
#                          Los Angeles                  1.056986
#                          Baltimore                    1.031781
#                          Rockford                     1.023014
#                          Peoria                       1.008493
# Cuba                     Havana                       1.000845
# United States            Albany                       0.993425
#                          Fort Wayne                   0.988493
# Ivory Coast              Abidjan                      0.962396
# United States            Corpus Christi               0.949863
# Ethiopia                 Addis Ababa                  0.945322
# United States            Sault Ste Marie              0.932055
# Japan                    Sapporo                      0.932033
# New Zealand              Auckland                     0.920670
# United States            El Paso                      0.907671
# Mozambique               Maputo                       0.904533
# United States            Topeka                       0.895616
#                          Amarillo                     0.886849
# Togo                     Lome                         0.881270
# United States            Duluth                       0.876712
# Madagascar               Antananarivo                 0.876056
# Brazil                   Rio de Janeiro               0.860446
# United States            Grand Rapids                 0.853973
#                          Denver                       0.853247
#                          Wilkes Barre                 0.841160
# Panama                   Panama City                  0.827019
# Gambia                   Banjul                       0.822419
# United States            Hartford Springfield         0.812877
# Benin                    Cotonou                      0.807872
# United States            Newark                       0.784110
#                          Phoenix                      0.783836
# Gabon                    Libreville                   0.778819
# United States            San Diego                    0.758356
# Belgium                  Brussels                     0.754596
# Tunisia                  Tunis                        0.698329
# United States            Tulsa                        0.693973
#                          Omaha                        0.688219
#                          Philadelphia                 0.671507
#                          Pittsburgh                   0.665753
# China                    Beijing                      0.621170
# Switzerland              Bern                         0.609749
# Senegal                  Dakar                        0.607242
# United States            Las Vegas                    0.579178
#                          Honolulu                     0.555068
# Guinea                   Conakry                      0.535776
# Bolivia                  La Paz                       0.522500
# United States            Austin                       0.504658
#                          Springfield                  0.503288
# Costa Rica               San Jose                     0.472910
# United States            Houston                      0.455342
# Algeria                  Algiers                      0.450980
# United States            Boise                        0.432877
# Equador                  Guayaquil                    0.414583
# United States            Detroit                      0.401644
#                          Lincoln                      0.401096
#                          Kansas City                  0.382192
#                          New York City                0.381370
#                          Dallas Ft Worth              0.380822
#                          San Antonio                  0.380548
# Spain                    Barcelona                    0.335097
# United States            Lubbock                      0.315342
# Guatemala                Guatemala City               0.310870
# United States            Rhode Island                 0.298082
# France                   Bordeaux                     0.297784
# United States            Portland                     0.266712
# Congo                    Brazzaville                  0.252632
# United States            Sacramento                   0.251801
#                          Shreveport                   0.244932
# Spain                    Bilbao                       0.232778
# Belize                   Belize City                  0.208108
# United States            Lake Charles                 0.206575
#                          Oklahoma City                0.184658
# United Kingdom           London                       0.121727
# United States            Wichita Falls                0.100274
# Sri Lanka                Colombo                      0.034857
# United States            St Louis                     0.030959
#                          Syracuse                     0.026575
#                          Tucson                       0.020274
#                          Goodland                    -0.012222
# Suriname                 Paramaribo                  -0.015385
# United States            Rochester                   -0.041209
#                          South Bend                  -0.046429
#                          Spokane                     -0.093151
#                          Buffalo                     -0.112877
#                          Des Moines                  -0.113151
#                          Salt Lake City              -0.152329
# India                    Calcutta                    -0.164888
# United States            Concord                     -0.176081
# Ireland                  Dublin                      -0.226184
# United States            Medford                     -0.236712
# Laos                     Vientiane                   -0.270195
# Nepal                    Katmandu                    -0.279245
# United States            Milwaukee                   -0.308219
# Spain                    Madrid                      -0.333611
# United States            Seattle                     -0.339178
#                          Elkins                      -0.393557
# Oman                     Muscat                      -0.400000
# United States            Cheyenne                    -0.430411
#                          Chicago                     -0.461644
#                          Green Bay                   -0.466849
#                          Minneapolis St. Paul        -0.502466
#                          Burlington                  -0.527671
#                          Bridgeport                  -0.538292
#                          Little Rock                 -0.556164
#                          Sioux Falls                 -0.575616
#                          Evansville                  -0.616712
# Kenya                    Nairobi                     -0.622759
# United States            Helena                      -0.635616
# France                   Paris                       -0.687887
# United States            Madison                     -0.798904
#                          North Platte                -0.910685
#                          Bismarck                    -0.914795
# Mongolia                 Ulan-bator                  -0.955278
# United States            Sioux City                  -0.956319
#                          Eugene                      -1.065205
#                          Billings                    -1.123288
# Canada                   Regina                      -1.139286
# United States            Salem                       -1.160274
# Canada                   Quebec                      -1.280223
# United States            Grand Junction              -1.446027
# Guinea-Bissau            Bissau                      -1.622619
# United States            Albuquerque                 -1.641644
#                          Fargo                       -1.685753
#                          Pocatello                   -1.698630
#                          Great Falls                 -1.792329
#                          Caribou                     -1.991507
# Honduras                 Tegucigalpa                 -2.014080
# Morocco                  Rabat                       -2.467409
# United States            Yakima                      -2.471233
#                          Casper                      -2.478082
# Portugal                 Lisbon                      -2.487187
# Haiti                    Port au Prince              -2.897628
# United Kingdom           Belfast                     -3.049441
# United States            Rapid City                  -3.418904
# Mexico                   Monterrey                   -3.583565

# %% [markdown]
# We can plot the data to see which cities had the highest average increase in temperature from 1995 to 2019. We see that Anchorage, Alaska has the highest average increase with about 5.28 degrees.

# %%
plt.figure(figsize=(40,10))
plt.title("Top 10 Cities With Highest Increase in Temperature 1995 to 2019", fontsize=60)
plt.tick_params(labelsize=15)
plt.xlabel("Country, City", fontsize=20)
sns.barplot(x=final_temp_df.head(10).index, y=final_temp_df.head(10)['Temp_Difference'],palette='autumn')
plt.ylabel("Increase in Temperature", fontsize=20)
# Out:
# Text(0, 0.5, 'Increase in Temperature')

# %% [markdown]
# We can also do the opposite and see which contries had the highest average decrease in temperature from 1995 to 2019 and plot the data to make it clear. We can see that Monterry, Mexico has the highest average decrease with about -3.58 degrees.

# %%
opp_final_temp_df=temp_difference_df.sort_values(ascending=True)
plt.figure(figsize=(40,10))
plt.title("Top 10 Cities With Highest Decrease in Temperature from 1995 to 2019", fontsize=60)
plt.tick_params(labelsize=15)
plt.xlabel("Country, City", fontsize=20)
sns.barplot(x=opp_final_temp_df.head(10).index, y=opp_final_temp_df.head(10),palette='winter')
plt.ylabel("Decrease in Temperature", fontsize=20)
# Out:
# Text(0, 0.5, 'Decrease in Temperature')

# %% [markdown]
# Finally, it would be nice to plot this data on a world map in order to see the average temperature differences all over the world at once.

# %% [markdown]
# Here we are renaming columns so we can merge the map with the data so that it will show up once we plot it and we are checking to see if it worked with the City Fairbanks in Alaska.

# %%
map_df = gpd.read_file("../input/worldm/World_Map.shp")
map_dff=gpd.read_file("../input/wcities/a4013257-88d6-4a68-b916-234180811b2d202034-1-1fw6kym.nqo.shp")
map_dff=map_dff.rename(columns = {'CNTRY_NAME':'Country'})
map_dff=map_dff.rename(columns = {'CITY_NAME':'City'}) 
map_dff.loc[map_dff.City =='Fairbanks']
# Out:
#      FID  ObjectID       City GMI_ADMIN ADMIN_NAME FIPS_CNTRY        Country  \
# 302  303       179  Fairbanks   USA-ALK     Alaska         US  United States
#
#     STATUS    POP  POP_RANK         POP_CLASS  PORT_ID  LABEL_FLAG  \
# 302  Other  30224         7  Less than 50,000        0           0
#
#                         geometry
# 302  POINT (-147.65118 64.83874)

# %% [markdown]
# Now we are plotting the data on the map to see the all the cities with the average temperature differences represented as colored dots.

# %%
merged = pd.merge(map_dff,final_temp_df[['Temp_Difference']],on='City')
ax=map_df.plot(figsize=(20,12), color='none', edgecolor='gainsboro', zorder=3)
vmin, vmax = -4, 6
merged.plot(column='Temp_Difference',cmap='coolwarm', ax=ax)
sm = plt.cm.ScalarMappable(cmap='coolwarm', norm=plt.Normalize(vmax=vmax, vmin=vmin))
sm._A = []
cbar = plt.colorbar(sm)
ax.set_title('Average Temperature Increase from 1995 to 2020', fontdict={'fontsize': '40', 'fontweight' : '3'})
# Out:
# Text(0.5, 1.0, 'Average Temperature Increase from 1995 to 2020')
